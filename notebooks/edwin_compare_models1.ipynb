# %%
import sys
sys.path.append("../")

from haxml.utils import (
    get_stadiums,
    get_matches_metadata,
    train_test_split_matches_even_count,
    get_opposing_goalpost,
    stadium_distance,
    angle_from_goal,
    is_scored_goal,
    # my features
    get_positions_at_time,
    defender_feature, # closest defender, defenders within dist
    defender_box, # count defender within goal and shot in rect
    defender_cone, # count defenders between shot and goal in cone
    speed_ball
)
from haxml.evaluation import (
    summarize_split,
    style_columns,
    make_df,
    score_model,
    run_models,
    blank_plot,
    plot_errors_by_kicks,
    plot_errors_by_goals,
    plot_xg_histogram
)
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

# %%
stadiums = get_stadiums("../data/stadiums.json")
metadata = get_matches_metadata("../data/matches_metadata.csv")
train, test = train_test_split_matches_even_count(metadata)

# %%
print("Train Data:")
summarize_split(train)
print()
print("Test Data:")
summarize_split(test)
# Out:
# Train Data:
# Matches: 1,158
# Goals: 3,227
# Kicks: 94,478
# E(XG): 0.034
#
# Test Data:
# Matches: 1,158
# Goals: 3,233
# Kicks: 95,110
# E(XG): 0.034

# %%
def generate_rows_compare(match, stadium):
    """
    Generates target and features for each kick in the match.
    Produces many features for model comparison.
    Args:
        match: Inflated match data (dict).
        stadium: Stadium data (dict).
    Returns:
        Generator of dicts with values for each kick in the given match.
        Includes prediction target "ag" (actual goals) which is 1 for a scored
        goal (goal or error) and 0 otherwise, "index" which is the index of the
        kick in the match kick list, and all the other features needed for
        prediction and explanation.
    """
    for i, kick in enumerate(match["kicks"]):
        gp = get_opposing_goalpost(stadium, kick["fromTeam"])
        x = kick["fromX"]
        y = kick["fromY"]
        gx = gp["mid"]["x"]
        gy = gp["mid"]["y"]
        dist = stadium_distance(x, y, gx, gy)
        angle = angle_from_goal(x, y, gx, gy)
        defender_dist,closest_defender = defender_feature(match,kick,100)
        defenders_within_box,in_box = defender_box(match,stadium,kick)
        defenders_within_shot,in_shot = defender_cone(match,stadium,kick,1)
        ball_speed=speed_ball(match,kick,1)
        row = {
            "ag": 1 if is_scored_goal(kick) else 0,
            "index": i,
            "time": kick["time"],
            "x": x,
            "y": y,
            "goal_x": gx,
            "goal_y": gy,
            "goal_distance": dist,
            "goal_angle": angle,
            "team": kick["fromTeam"],
            "stadium": match["stadium"],
            "defender_dist": defender_dist, # numerical , numbers within a range
            "closest_defender": closest_defender, # numerical, distance of the closest 
            "defenders_within_box": defenders_within_box, # numerical, number of player(defenders) within goal and kick(ball)
            "in_box": in_box, # Boolean, Is there defenders in this boxb bteween goal and kick
            "defenders_within_shot": defenders_within_shot, # numerical, how many players(defenders) are in this cone
            "in_shot": in_shot, # Boolean, Is there defenders in this cone
            "ball_speed": ball_speed # numerical, speeds ball within a given time range
        }
        yield row

# %%
d_train = make_df(train, stadiums, generate_rows_compare, progress=True)
d_test = make_df(test, stadiums, generate_rows_compare, progress=True)
# Out:
# 100%|██████████| 1158/1158 [04:23<00:00,  4.40it/s]
# 100%|██████████| 1158/1158 [03:39<00:00,  5.27it/s]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
feature_sets = [
    ["goal_distance","goal_angle","defender_dist","closest_defender","defenders_within_box","in_box","in_shot","ball_speed"] # best model
    #["goal_distance","goal_angle"]
]

# %%
model_params = [
    (RandomForestClassifier, {"max_depth":12, "random_state":0}),
    (LogisticRegression, {"random_state": 0}),
    (DecisionTreeClassifier, {"max_depth": 5}),
    (KNeighborsClassifier, {"n_neighbors": 7}),
    (GradientBoostingClassifier, {"n_estimators":100, "learning_rate":1.0,"max_depth":1, "random_state":0}),
    (AdaBoostClassifier, {"n_estimators":100})
]

# %%
df_scored = run_models(d_train, d_test, score_model, "ag", feature_sets, model_params)
# Out:
# Model: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=12, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
# Model: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=12, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
# Model: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=12, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
# Model: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,/it]
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
# Model: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False):  17%|█▋        | 1/6 [00:09<00:48,  9.72s/it]/home/ezfire/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Model: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
# Model: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',t]
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
# Model: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',[00:10<00:28,  7.02s/it]
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
# Model: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',[00:10<00:28,  7.02s/it]
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
# Model: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',6 [00:10<00:15,  5.02s/it]
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
# Model: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',02s/it]
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
# Model: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',02s/it]
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
# Model: GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,]
#                            learning_rate=1.0, loss='deviance', max_depth=1,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
# Model: GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,4s/it]
#                            learning_rate=1.0, loss='deviance', max_depth=1,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
# Model: GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,4s/it]
#                            learning_rate=1.0, loss='deviance', max_depth=1,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
# Model: AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,s/it]
# Model: AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,0:04,  4.74s/it]
# Model: AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,0:04,  4.74s/it]
# Model: AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,0:00,  7.09s/it]
#                    n_estimators=100, random_state=None): 100%|██████████| 6/6 [00:32<00:00,  5.38s/it]

# %%
score_color = "94, 156, 255"
style_config = {
    "accuracy": {"rgb": score_color, "low": 0, "high": 1},
    "precision": {"rgb": score_color, "low": 0, "high": 1},
    "recall": {"rgb": score_color, "low": 0, "high": 1},
    "roc_auc": {"rgb": score_color, "low": 0.5, "high": 1},
    "match_mae": {"rgb": score_color, "low": 3, "high": 0},
    "match_rmse": {"rgb": score_color, "low": 3, "high": 0},
    "xg_mean": {"rgb": score_color, "low": 0, "high": 0.07},
    "xg_std": {"rgb": score_color, "low": 0, "high": 0.5},
}

# %%
df_ranked = df_scored \
    .sort_values(by=["precision", "roc_auc"], ascending=[False, False]) \
    .reset_index()
df_ranked \
    [["clf", "features"] + list(style_config.keys())] \
    .style.apply(style_columns(style_config)) \
    .set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col2 {
#             background-color:  rgba(94, 156, 255, 0.969971611817895);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col3 {
#             background-color:  rgba(94, 156, 255, 0.757162346521146);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col4 {
#             background-color:  rgba(94, 156, 255, 0.17166718218373028);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col5 {
#             background-color:  rgba(94, 156, 255, 0.16972980939184557);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col6 {
#             background-color:  rgba(94, 156, 255, 0.5781082349301355);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col7 {
#             background-color:  rgba(94, 156, 255, 0.47242576491842625);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col8 {
#             background-color:  rgba(94, 156, 255, 0.4822345943417252);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col9 {
#             background-color:  rgba(94, 156, 255, 0.17506787238719332);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col2 {
#             background-color:  rgba(94, 156, 255, 0.9666386289559458);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col3 {
#             background-color:  rgba(94, 156, 255, 0.5255536626916525);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col4 {
#             background-color:  rgba(94, 156, 255, 0.19084441695020105);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col5 {
#             background-color:  rgba(94, 156, 255, 0.18478196388795487);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col6 {
#             background-color:  rgba(94, 156, 255, 0.523339908720835);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col7 {
#             background-color:  rgba(94, 156, 255, 0.3974834821466318);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col8 {
#             background-color:  rgba(94, 156, 255, 0.49122284256361537);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow1_col9 {
#             background-color:  rgba(94, 156, 255, 0.1773111676922043);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col2 {
#             background-color:  rgba(94, 156, 255, 0.9660603511723268);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col3 {
#             background-color:  rgba(94, 156, 255, 0.5019700551615445);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col4 {
#             background-color:  rgba(94, 156, 255, 0.1970306217135787);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col5 {
#             background-color:  rgba(94, 156, 255, 0.19015185989070704);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col6 {
#             background-color:  rgba(94, 156, 255, 0.5206020231926968);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col7 {
#             background-color:  rgba(94, 156, 255, 0.3978337238036025);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col8 {
#             background-color:  rgba(94, 156, 255, 0.4732007407105413);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow2_col9 {
#             background-color:  rgba(94, 156, 255, 0.2150338802207728);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col2 {
#             background-color:  rgba(94, 156, 255, 0.9651876774261382);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col3 {
#             background-color:  rgba(94, 156, 255, 0.4622093023255814);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col4 {
#             background-color:  rgba(94, 156, 255, 0.14754098360655737);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col5 {
#             background-color:  rgba(94, 156, 255, 0.1415002987779277);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col6 {
#             background-color:  rgba(94, 156, 255, 0);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col7 {
#             background-color:  rgba(94, 156, 255, 0);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col8 {
#             background-color:  rgba(94, 156, 255, 1);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow3_col9 {
#             background-color:  rgba(94, 156, 255, 0.0634174205121766);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col2 {
#             background-color:  rgba(94, 156, 255, 0.9651771632846178);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col3 {
#             background-color:  rgba(94, 156, 255, 0.43471074380165287);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col4 {
#             background-color:  rgba(94, 156, 255, 0.08134859263841633);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col5 {
#             background-color:  rgba(94, 156, 255, 0.0776262246899635);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col6 {
#             background-color:  rgba(94, 156, 255, 0.5779607002757351);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col7 {
#             background-color:  rgba(94, 156, 255, 0.46506101954493656);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col8 {
#             background-color:  rgba(94, 156, 255, 0.49433441866866284);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow4_col9 {
#             background-color:  rgba(94, 156, 255, 0.1657588674374705);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col2 {
#             background-color:  rgba(94, 156, 255, 0.9491956681736936);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col3 {
#             background-color:  rgba(94, 156, 255, 0.2516309412861137);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col4 {
#             background-color:  rgba(94, 156, 255, 0.25054129291679555);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col5 {
#             background-color:  rgba(94, 156, 255, 0.22432145552550087);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col6 {
#             background-color:  rgba(94, 156, 255, 0.10049875756513178);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col7 {
#             background-color:  rgba(94, 156, 255, 0);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col8 {
#             background-color:  rgba(94, 156, 255, 0.846895399233969);
#         }    #T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow5_col9 {
#             background-color:  rgba(94, 156, 255, 0.352138196948206);
#         }</style><table id="T_c232d8ec_5c1a_11eb_bf3b_937b91da4adb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >clf</th>        <th class="col_heading level0 col1" >features</th>        <th class="col_heading level0 col2" >accuracy</th>        <th class="col_heading level0 col3" >precision</th>        <th class="col_heading level0 col4" >recall</th>        <th class="col_heading level0 col5" >roc_auc</th>        <th class="col_heading level0 col6" >match_mae</th>        <th class="col_heading level0 col7" >match_rmse</th>        <th class="col_heading level0 col8" >xg_mean</th>        <th class="col_heading level0 col9" >xg_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c232d8ec_5c1a_11eb_bf3b_937b91da4adblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c232d8ec_5c1a_11eb_bf3b_937b91da4adbrow0_col0" class="data row0 col0" >RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=12, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)</td>
#                         <td id="T_c232d8ec_
